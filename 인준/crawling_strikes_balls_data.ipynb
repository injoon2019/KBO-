# %%
# 데이터 크롤링 모듈
from bs4 import BeautifulSoup
import re
# 데이터 분석 모듈
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from datetime import datetime
import requests
import json

# %%
df = pd.read_csv(r'C:\Users\injoo\광주 인공지능 사관학교\웜업 프로젝트\KBO 데이터 시각화\인준\game_schedule_for_strikes.csv')
df = df.drop(columns = ['Unnamed: 0', 'Month', 'PlaceName'])

# %%
df
# Out:
#        Date HomeName AwayName  HomeScore  AwayScore  IsHomeWin
# 0    200505      LGT      DSB          8          2          2
# 1    200505      SKW      HHE          0          3          0
# 2    200505      SSL      NCD          0          4          0
# 3    200505      KTW      LTG          2          7          0
# 4    200505      KIA      KWH          2         11          0
# ..      ...      ...      ...        ...        ...        ...
# 467  200901      DSB      HHE          4          0          2
# 468  200901      SKW      LGT          5         13          0
# 469  200901      KTW      LTG         11          2          2
# 470  200901      KIA      SSL          6          0          2
# 471  200901      KWH      NCD          2          5          0
#
# [472 rows x 6 columns]

# %%
games_list = df.values.tolist()

# %%
games_list
# Out:
# [[200505, 'LGT', 'DSB', 8, 2, 2],
#  [200505, 'SKW', 'HHE', 0, 3, 0],
#  [200505, 'SSL', 'NCD', 0, 4, 0],
#  [200505, 'KTW', 'LTG', 2, 7, 0],
#  [200505, 'KIA', 'KWH', 2, 11, 0],
#  [200506, 'LGT', 'DSB', 2, 5, 0],
#  [200506, 'SKW', 'HHE', 5, 2, 2],
#  [200506, 'SSL', 'NCD', 3, 4, 0],
#  [200506, 'KTW', 'LTG', 4, 9, 0],
#  [200506, 'KIA', 'KWH', 2, 3, 0],
#  [200507, 'LGT', 'DSB', 3, 9, 0],
#  [200507, 'SKW', 'HHE', 4, 8, 0],
#  [200507, 'SSL', 'NCD', 2, 8, 0],
#  [200507, 'KTW', 'LTG', 3, 7, 0],
#  [200507, 'KIA', 'KWH', 8, 5, 2],
#  [200508, 'DSB', 'KTW', 3, 12, 0],
#  [200508, 'LTG', 'SKW', 9, 8, 2],
#  [200508, 'SSL', 'KIA', 5, 0, 2],
#  [200508, 'NCD', 'LGT', 13, 5, 2],
#  [200508, 'KWH', 'HHE', 5, 3, 2],
#  [200509, 'SSL', 'KIA', 14, 2, 2],
#  [200509, 'KWH', 'HHE', 5, 3, 2],
#  [200510, 'DSB', 'KTW', 13, 12, 2],
#  [200510, 'LTG', 'SKW', 4, 0, 2],
#  [200510, 'SSL', 'KIA', 3, 12, 0],
#  [200510, 'NCD', 'LGT', 8, 10, 0],
#  [200510, 'KWH', 'HHE', 6, 3, 2],
# ...

# %%
print(len(games_list))
# Out:
# 472

# %%
column_list = ["Umpire", "Away", "Away_strikes", "Away_balls", "Home_strikes", "Home_balls"]
df = pd.DataFrame(column_list)
for row in games_list:
    add_dict = {"Umpire": None, "Away": None, "Away_strikes":None, "Away_balls":None, "Home_strikes":None, "Home_balls":None}
    rest_url = str(row[0])+row[2]+row[1]
    
    response = requests.get("https://strikes.zone/game/"+rest_url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    #심판의 이름을 가져오는 코드
    umpire_tag = soup.find(class_= "match__date")
    umpire = str(re.findall('\(.+\)', str(umpire_tag)))
    
    umpire_dict = dict()
    print(rest_url, row[0], umpire)
# Out:
# 200505DSBLGT 200505 ['(이영재 심판)']
# 200505HHESKW 200505 ['(최수원 심판)']
# 200505NCDSSL 200505 ['(강광회 심판)']
# 200505LTGKTW 200505 ['(박기택 심판)']
# 200505KWHKIA 200505 ['(전일수 심판)']
# 200506DSBLGT 200506 ['(김익수 심판)']
# 200506HHESKW 200506 ['(김준희 심판)']
# 200506NCDSSL 200506 ['(김정국 심판)']
# 200506LTGKTW 200506 ['(이계성 심판)']
# 200506KWHKIA 200506 ['(문동균 심판)']
# 200507DSBLGT 200507 ['(추평호 심판)']
# 200507HHESKW 200507 ['(이기중 심판)']
# 200507NCDSSL 200507 ['(박근영 심판)']
# 200507LTGKTW 200507 ['(오훈규 심판)']
# 200507KWHKIA 200507 ['(권영철 심판)']
# 200508KTWDSB 200508 ['(박종철 심판)']
# 200508SKWLTG 200508 ['(이민호 심판)']
# 200508KIASSL 200508 ['(함지웅 심판)']
# 200508LGTNCD 200508 ['(장준영 심판)']
# 200508HHEKWH 200508 ['(구명환 심판)']
# 200509KIASSL 200509 ['(문승훈 심판)']
# 200509HHEKWH 200509 ['(나광남 심판)']
# 200510KTWDSB 200510 ['(배병두 심판)']
# 200510SKWLTG 200510 ['(이용혁 심판)']
# 200510KIASSL 200510 ['(정종수 심판)']
# 200510LGTNCD 200510 ['(김병주 심판)']
# 200510HHEKWH 200510 ['(유덕형 심판)']
# 200512SKWLGT 200512 ['(전일수 심판)']
# ...

# %%
response = requests.get("https://strikes.zone/game/200505DSBLGT")
soup = BeautifulSoup(response.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE doctype html>
#
# <html data-n-head="" data-n-head-ssr="">
# <head data-n-head="">
# ...

# %%
response = requests.get("https://strikes.zone/game/200505DSBLGT")
soup = BeautifulSoup(response.text, "html.parser")
print(soup.find())
# Out:
# 26826

# %%
response = requests.get("https://sports.news.naver.com/gameCenter/gameResult.nhn?category=kbo&gameId=20200901LTKT02020")
soup = BeautifulSoup(response.text, "html.parser")
print(soup.find())
# Out:
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image">
# <meta content="" property="og:title">
# <meta content="스포츠의 시작과 끝!" property="og:description">
# <meta content="https://sports.news.naver.com/gameCenter/gameResult.nhn?category=kbo&amp;gameId=20200901LTKT02020" property="og:url"/>
# <title>롯데 vs KT, 경기결과, 게임센터, 프로야구 : 네이버 스포츠</title>
# <link href="/favicon.ico?v=20140331" otype="image/x-icon" rel="shortcut icon"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2020/09/03/120050/css/common_loose_new.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2020/09/03/120050/css/gamecenter.css" rel="stylesheet" type="text/css"/>
# ...
