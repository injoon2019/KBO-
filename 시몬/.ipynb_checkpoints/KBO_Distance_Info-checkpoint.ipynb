# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
# 데이터 크롤링 모듈
from bs4 import BeautifulSoup
import re

# %%
# 데이터 분석 모듈
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from datetime import datetime
import requests

# %%
pd.set_option("display.max_rows", 5000)
pd.set_option("display.max_columns", 5000)


# KBO 크롤링
# 우선 타자 분석이라 예시로 가져옴
site_list_num = 1
url = f"https://www.koreabaseball.com/Record/Player/HitterBasic/Basic{site_list_num}.aspx"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# 선수들 데이터 목록 가져옴
Player_infos = soup.find_all("tr")

list_columns = ["순위", "선수명", "팀명", "타율", "경기수", "타석", "타수", "득점", "안타", "2루타",
                "3루타", "홈런","루타","타점", "희생번트", "희생플라이"]
df_pl_data = pd.DataFrame(columns=list_columns)

bodys = soup.select("div[id=cphContents_cphContents_cphContents_udpContent] > div[class=record_result] > table > tbody > tr")


for pl_infos in bodys:

    list_tds = pl_infos.select("td")

    row_datas = []
    for td in list_tds:
        row_datas.append(td.text)

    series = pd.Series(row_datas, index=list_columns)
    df_pl_data = df_pl_data.append(series, ignore_index=True)

# %%
import requests

cookies = {
    '_ga': 'GA1.2.930351172.1597235144',
    'Cookie_Id': 'didtlahs652',
    'ASP.NET_SessionId': 'hz0on0sdkdomw3nqzri3j4sk',
    '_gid': 'GA1.2.970217577.1599027608',
    '_gat': '1',
}

headers = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'X-Requested-With': 'XMLHttpRequest',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Whale/2.8.105.22 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.koreabaseball.com',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://www.koreabaseball.com/Schedule/Schedule.aspx',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
}

# %%
list_columns = ["Month", "Date", "PlaceName", "HomeName", "AwayName", "HomeScore", "AwayScore", "IsHomeWin"]


save_date = None
df_match_days = pd.DataFrame(columns=list_columns)

for month in range(5, datetime.today().month + 1):

    data = {
      'leId': '1',
      'srIdList': '0,9',
      'seasonId': '2020',
        # 'gameMonth': "09",
      'gameMonth': str(month).zfill(2),
      'teamId': ''
    }

    # JSON
    response = requests.post('https://www.koreabaseball.com/ws/Schedule.asmx/GetScheduleList', headers=headers, cookies=cookies, data=data)
    json_data = json.loads(response.text)

    list_rows = json_data["rows"]

    for rows in list_rows:
        dic_add = {"Month":None, "Date": None, "PlaceName": None, "HomeName":None,
                   "AwayName" : None, "HomeScore":None, "AwayScore":None, "IsHomeWin" : None}
        rows = rows["row"]
        minus_idx = -1

        # 날짜 있는 데이터들 때문에 minus idx 해줌 행순서때문에.
        if rows[0]['Class'] == "day":
            save_date = rows[0]["Text"]
            minus_idx = 0
        # 우천취소시 데이터에 담지 않음 \ 그라운드사정
        if rows[8 + minus_idx]["Text"] != "-":
            continue

        # Month Day

        dic_add["Month"] = month
        dic_add["Date"] = save_date

        if month == datetime.today().month:
            data_day = int(save_date.split('.')[1][:2])
            real_today = datetime.today().today().day
            if data_day >=real_today :
                continue

        dic_add["PlaceName"] = rows[7 + minus_idx]["Text"]
        dic_add["HomeName"] = rows[2 + minus_idx]["Text"].lstrip("<span>").split("<")[0]
        dic_add["HomeName"] = rows[2 + minus_idx]["Text"].lstrip("<span>").split("<")[0]

        # MATCH STRING DATA
        match_data = rows[2 + minus_idx]["Text"].lstrip("<span>").rstrip("</span>")

        # SCORE
        score = re.findall('\d+', match_data)

        dic_add["HomeScore"] = int(score[1])
        dic_add["AwayScore"] = int(score[0])

        # HOME WIN ??
        if dic_add["HomeScore"] > dic_add["AwayScore"] :
            dic_add["IsHomeWin"] = 2
        elif dic_add["HomeScore"] == dic_add["AwayScore"] :
            # 비기면 1
            dic_add["IsHomeWin"] = 1
        else:
            dic_add["IsHomeWin"] = 0

        # CLUB NAME
        list_club_name = re.sub('<.*>', '.', match_data).split(".")
        dic_add["HomeName"] = list_club_name[1]
        dic_add["AwayName"] = list_club_name[0]

        df_match_days = df_match_days.append(dic_add, ignore_index=True)




df_match_days
# Out:
#     Month      Date PlaceName HomeName AwayName HomeScore AwayScore IsHomeWin
# 0       5  05.05(화)        잠실       LG       두산         8         2         2
# 1       5  05.05(화)        문학       SK       한화         0         3         0
# 2       5  05.05(화)        대구       삼성       NC         0         4         0
# 3       5  05.05(화)        수원       KT       롯데         2         7         0
# 4       5  05.05(화)        광주      KIA       키움         2        11         0
# 5       5  05.06(수)        잠실       LG       두산         2         5         0
# 6       5  05.06(수)        문학       SK       한화         5         2         2
# 7       5  05.06(수)        대구       삼성       NC         3         4         0
# 8       5  05.06(수)        수원       KT       롯데         4         9         0
# 9       5  05.06(수)        광주      KIA       키움         2         3         0
# 10      5  05.07(목)        잠실       LG       두산         3         9         0
# 11      5  05.07(목)        문학       SK       한화         4         8         0
# 12      5  05.07(목)        대구       삼성       NC         2         8         0
# 13      5  05.07(목)        수원       KT       롯데         3         7         0
# 14      5  05.07(목)        광주      KIA       키움         8         5         2
# 15      5  05.08(금)        잠실       두산       KT         3        12         0
# 16      5  05.08(금)        사직       롯데       SK         9         8         2
# 17      5  05.08(금)        대구       삼성      KIA         5         0         2
# 18      5  05.08(금)        창원       NC       LG        13         5         2
# 19      5  05.08(금)        고척       키움       한화         5         3         2
# 20      5  05.09(토)        대구       삼성      KIA        14         2         2
# 21      5  05.09(토)        고척       키움       한화         5         3         2
# 22      5  05.10(일)        잠실       두산       KT        13        12         2
# 23      5  05.10(일)        사직       롯데       SK         4         0         2
# 24      5  05.10(일)        대구       삼성      KIA         3        12         0
# 25      5  05.10(일)        창원       NC       LG         8        10         0
# 26      5  05.10(일)        고척       키움       한화         6         3         2
# 27      5  05.12(화)        잠실       LG       SK         9         5         2
# 28      5  05.12(화)        사직       롯데       두산         6        11         0
# 29      5  05.12(화)        창원       NC       KT         7         6         2
# 30      5  05.12(화)        고척       키움       삼성         3         2         2
# 31      5  05.12(화)        대전       한화      KIA         1         2         0
# 32      5  05.13(수)        잠실       LG       SK        14         2         2
# 33      5  05.13(수)        사직       롯데       두산        10         9         2
# 34      5  05.13(수)        창원       NC       KT         5         4         2
# 35      5  05.13(수)        고척       키움       삼성         0         5         0
# 36      5  05.13(수)        대전       한화      KIA         3         4         0
# 37      5  05.14(목)        잠실       LG       SK         3         2         2
# 38      5  05.14(목)        사직       롯데       두산         4         7         0
# 39      5  05.14(목)        창원       NC       KT         1         0         2
# 40      5  05.14(목)        고척       키움       삼성         5         8         0
# 41      5  05.14(목)        대전       한화      KIA         4         1         2
# 42      5  05.15(금)        문학       SK       NC         2         6         0
# 43      5  05.15(금)        수원       KT       삼성        14         6         2
# 44      5  05.15(금)        광주      KIA       두산         4        13         0
# 45      5  05.15(금)        대전       한화       롯데         2         1         2
# 46      5  05.16(토)        대전       한화       롯데         1         5         0
# 47      5  05.16(토)        잠실       LG       키움         3         1         2
# 48      5  05.16(토)        문학       SK       NC         1         2         0
# 49      5  05.16(토)        수원       KT       삼성        10         4         2
# 50      5  05.16(토)        광주      KIA       두산        13         4         2
# 51      5  05.16(토)        잠실       LG       키움         5         3         2
# 52      5  05.17(일)        잠실       LG       키움         4         9         0
# 53      5  05.17(일)        문학       SK       NC         5        11         0
# 54      5  05.17(일)        수원       KT       삼성         9         2         2
# 55      5  05.17(일)        광주      KIA       두산         4         6         0
# 56      5  05.17(일)        대전       한화       롯데         5         4         2
# 57      5  05.19(화)        잠실       두산       NC         4         5         0
# 58      5  05.19(화)        대구       삼성       LG         6        10         0
# 59      5  05.19(화)        수원       KT       한화        13        11         2
# 60      5  05.19(화)        광주      KIA       롯데         9         2         2
# 61      5  05.19(화)        고척       키움       SK        11         6         2
# 62      5  05.20(수)        잠실       두산       NC         2         1         2
# 63      5  05.20(수)        대구       삼성       LG         3         1         2
# 64      5  05.20(수)        수원       KT       한화         8         1         2
# 65      5  05.20(수)        광주      KIA       롯데         6         0         2
# 66      5  05.20(수)        고척       키움       SK         3         5         0
# 67      5  05.21(목)        잠실       두산       NC         6        12         0
# 68      5  05.21(목)        대구       삼성       LG         0         2         0
# 69      5  05.21(목)        수원       KT       한화         4         9         0
# 70      5  05.21(목)        광주      KIA       롯데         6         1         2
# 71      5  05.21(목)        고척       키움       SK         9         8         2
# 72      5  05.22(금)        잠실       LG       KT         6         5         2
# 73      5  05.22(금)        문학       SK      KIA         1         2         0
# 74      5  05.22(금)        사직       롯데       키움         9         7         2
# 75      5  05.22(금)        대구       삼성       두산         7        12         0
# 76      5  05.22(금)        창원       NC       한화         3         5         0
# 77      5  05.23(토)        잠실       LG       KT         2         6         0
# 78      5  05.23(토)        문학       SK      KIA         3         8         0
# 79      5  05.23(토)        사직       롯데       키움         4        12         0
# 80      5  05.23(토)        대구       삼성       두산         6        10         0
# 81      5  05.23(토)        창원       NC       한화         3         0         2
# 82      5  05.24(일)        잠실       LG       KT         9         7         2
# 83      5  05.24(일)        문학       SK      KIA         4         3         2
# 84      5  05.24(일)        사직       롯데       키움         2         0         2
# 85      5  05.24(일)        대구       삼성       두산        13         0         2
# 86      5  05.24(일)        창원       NC       한화        10         5         2
# 87      5  05.26(화)        잠실       두산       SK         6         4         2
# 88      5  05.26(화)        사직       롯데       삼성         1         0         2
# 89      5  05.26(화)        창원       NC       키움         7         2         2
# 90      5  05.26(화)        수원       KT      KIA         1         4         0
# 91      5  05.26(화)        대전       한화       LG         0         3         0
# 92      5  05.27(수)        잠실       두산       SK         4         2         2
# 93      5  05.27(수)        사직       롯데       삼성         1        11         0
# 94      5  05.27(수)        창원       NC       키움        10         3         2
# 95      5  05.27(수)        수원       KT      KIA         5         0         2
# 96      5  05.27(수)        대전       한화       LG         4        15         0
# 97      5  05.28(목)        잠실       두산       SK         1         6         0
# 98      5  05.28(목)        사직       롯데       삼성         1         3         0
# 99      5  05.28(목)        창원       NC       키움         9         6         2
# 100     5  05.28(목)        수원       KT      KIA         6         5         2
# 101     5  05.28(목)        대전       한화       LG         0         3         0
# 102     5  05.29(금)        잠실       두산       롯데         4         2         2
# 103     5  05.29(금)        문학       SK       한화         8         6         2
# 104     5  05.29(금)        대구       삼성       NC         5         4         2
# 105     5  05.29(금)        광주      KIA       LG         2         6         0
# 106     5  05.29(금)        고척       키움       KT         5         1         2
# 107     5  05.30(토)        광주      KIA       LG        10         6         2
# 108     5  05.30(토)        잠실       두산       롯데         5         4         2
# 109     5  05.30(토)        문학       SK       한화         9         3         2
# 110     5  05.30(토)        대구       삼성       NC         9         1         2
# 111     5  05.30(토)        고척       키움       KT        14         3         2
# 112     5  05.31(일)        잠실       두산       롯데         3         8         0
# 113     5  05.31(일)        문학       SK       한화         6         4         2
# 114     5  05.31(일)        대구       삼성       NC         7        18         0
# 115     5  05.31(일)        광주      KIA       LG         5        13         0
# 116     5  05.31(일)        고척       키움       KT         8        12         0
# 117     6  06.02(화)        잠실       LG       삼성         0         2         0
# 118     6  06.02(화)        창원       NC       SK         2         8         0
# 119     6  06.02(화)        수원       KT       두산         8        11         0
# 120     6  06.02(화)        광주      KIA       롯데         7         2         2
# 121     6  06.02(화)        대전       한화       키움         3        15         0
# 122     6  06.03(수)        잠실       LG       삼성         6        12         0
# 123     6  06.03(수)        창원       NC       SK         8         6         2
# 124     6  06.03(수)        수원       KT       두산         7         2         2
# 125     6  06.03(수)        광주      KIA       롯데        11         2         2
# 126     6  06.03(수)        대전       한화       키움         2         6         0
# 127     6  06.04(목)        잠실       LG       삼성        11         0         2
# 128     6  06.04(목)        창원       NC       SK        10         0         2
# 129     6  06.04(목)        수원       KT       두산         8        14         0
# 130     6  06.04(목)        광주      KIA       롯데         7         3         2
# 131     6  06.04(목)        대전       한화       키움         3         7         0
# 132     6  06.05(금)        잠실       두산      KIA         5         1         2
# 133     6  06.05(금)        문학       SK       삼성         4         1         2
# 134     6  06.05(금)        사직       롯데       KT         6         4         2
# 135     6  06.05(금)        고척       키움       LG         6         3         2
# 136     6  06.05(금)        대전       한화       NC         2        13         0
# 137     6  06.06(토)        잠실       두산      KIA         4         3         2
# 138     6  06.06(토)        대전       한화       NC         2        14         0
# 139     6  06.06(토)        문학       SK       삼성         6         4         2
# 140     6  06.06(토)        사직       롯데       KT         1         0         2
# 141     6  06.06(토)        고척       키움       LG         5         4         2
# 142     6  06.07(일)        잠실       두산      KIA         3         2         2
# 143     6  06.07(일)        문학       SK       삼성         0         3         0
# 144     6  06.07(일)        사직       롯데       KT         5         2         2
# 145     6  06.07(일)        고척       키움       LG         1         8         0
# 146     6  06.07(일)        대전       한화       NC         2         8         0
# 147     6  06.09(화)        잠실       LG       SK         3         5         0
# 148     6  06.09(화)        사직       롯데       한화         9         3         2
# 149     6  06.09(화)        대구       삼성       키움         3         5         0
# 150     6  06.09(화)        창원       NC       두산        12         8         2
# 151     6  06.09(화)        수원       KT      KIA         2         3         0
# 152     6  06.10(수)        사직       롯데       한화        12         2         2
# 153     6  06.10(수)        대구       삼성       키움         4         1         2
# 154     6  06.10(수)        창원       NC       두산         1         9         0
# 155     6  06.10(수)        수원       KT      KIA         0        10         0
# 156     6  06.11(목)        잠실       LG       SK         3         1         2
# 157     6  06.11(목)        잠실       LG       SK         4         3         2
# 158     6  06.11(목)        사직       롯데       한화         5         0         2
# 159     6  06.11(목)        대구       삼성       키움         6         3         2
# 160     6  06.11(목)        창원       NC       두산         7         5         2
# 161     6  06.11(목)        수원       KT      KIA        13         8         2
# 162     6  06.12(금)        잠실       LG       롯데         3         2         2
# 163     6  06.12(금)        문학       SK      KIA         3         6         0
# 164     6  06.12(금)        창원       NC       키움         2         3         0
# 165     6  06.12(금)        대전       한화       두산         2         5         0
# 166     6  06.13(토)        대구       삼성       KT         5         3         2
# 167     6  06.13(토)        잠실       LG       롯데         6         7         0
# 168     6  06.13(토)        문학       SK      KIA         1         2         0
# 169     6  06.13(토)        창원       NC       키움         5        18         0
# 170     6  06.13(토)        대전       한화       두산         7         6         2
# 171     6  06.13(토)        대구       삼성       KT         4         7         0
# 172     6  06.14(일)        잠실       LG       롯데        10         6         2
# 173     6  06.14(일)        문학       SK      KIA         4         3         2
# 174     6  06.14(일)        대구       삼성       KT        12         0         2
# 175     6  06.14(일)        창원       NC       키움         9         5         2
# 176     6  06.14(일)        대전       한화       두산         3         2         2
# 177     6  06.16(화)        잠실       두산       삼성         3         4         0
# 178     6  06.16(화)        문학       SK       KT         5         6         0
# 179     6  06.16(화)        광주      KIA       NC         7         4         2
# 180     6  06.16(화)        고척       키움       롯데         5         7         0
# 181     6  06.16(화)        대전       한화       LG         5         9         0
# 182     6  06.17(수)        잠실       두산       삼성         3         6         0
# 183     6  06.17(수)        문학       SK       KT         4         6         0
# 184     6  06.17(수)        광주      KIA       NC         7         6         2
# 185     6  06.17(수)        고척       키움       롯데         4         3         2
# 186     6  06.17(수)        대전       한화       LG         1         7         0
# 187     6  06.18(목)        잠실       두산       삼성         7         3         2
# 188     6  06.18(목)        문학       SK       KT         3         5         0
# 189     6  06.18(목)        고척       키움       롯데         3         2         2
# 190     6  06.18(목)        대전       한화       LG         7         9         0
# 191     6  06.19(금)        잠실       LG       두산        10        18         0
# 192     6  06.19(금)        창원       NC       한화         3         1         2
# 193     6  06.19(금)        수원       KT       롯데         9         8         2
# 194     6  06.19(금)        광주      KIA       삼성         5         4         2
# 195     6  06.19(금)        고척       키움       SK         2         1         2
# 196     6  06.20(토)        잠실       LG       두산         2         8         0
# 197     6  06.20(토)        창원       NC       한화         3         4         0
# 198     6  06.20(토)        수원       KT       롯데         0         8         0
# 199     6  06.20(토)        광주      KIA       삼성         6         3         2
# 200     6  06.20(토)        고척       키움       SK         9         3         2
# 201     6  06.21(일)        잠실       LG       두산         1         3         0
# 202     6  06.21(일)        창원       NC       한화         9         7         2
# 203     6  06.21(일)        수원       KT       롯데         3         2         2
# 204     6  06.21(일)        광주      KIA       삼성         5        12         0
# 205     6  06.21(일)        고척       키움       SK         7         2         2
# 206     6  06.23(화)        잠실       LG       키움         3         8         0
# 207     6  06.23(화)        문학       SK       두산         2         9         0
# 208     6  06.23(화)        사직       롯데      KIA         4         3         2
# 209     6  06.23(화)        대구       삼성       한화        11         4         2
# 210     6  06.23(화)        수원       KT       NC         3         4         0
# 211     6  06.24(수)        대구       삼성       한화         3         2         2
# 212     6  06.25(목)        잠실       LG       키움         2         5         0
# 213     6  06.25(목)        문학       SK       두산         6        14         0
# 214     6  06.25(목)        수원       KT       NC         1         3         0
# 215     6  06.25(목)        잠실       LG       키움         5         8         0
# 216     6  06.25(목)        문학       SK       두산         7         0         2
# 217     6  06.25(목)        수원       KT       NC        19         6         2
# 218     6  06.25(목)        대구       삼성       한화         2         9         0
# 219     6  06.26(금)        잠실       두산       NC         3         9         0
# 220     6  06.26(금)        문학       SK       LG         7         0         2
# 221     6  06.26(금)        사직       롯데       삼성         4         6         0
# 222     6  06.26(금)        고척       키움      KIA         6         8         0
# 223     6  06.26(금)        대전       한화       KT         7         4         2
# 224     6  06.27(토)        잠실       두산       NC        12         3         2
# 225     6  06.27(토)        문학       SK       LG         0         3         0
# 226     6  06.27(토)        사직       롯데       삼성         1         6         0
# 227     6  06.27(토)        고척       키움      KIA         2         0         2
# 228     6  06.27(토)        대전       한화       KT         2         7         0
# 229     6  06.28(일)        잠실       두산       NC         0         5         0
# 230     6  06.28(일)        문학       SK       LG         0         4         0
# 231     6  06.28(일)        사직       롯데       삼성         7         3         2
# 232     6  06.28(일)        고척       키움      KIA         1         0         2
# 233     6  06.28(일)        대전       한화       KT         4         8         0
# 234     6  06.30(화)        잠실       LG       KT         4         3         2
# 235     6  06.30(화)        대구       삼성       SK         4         1         2
# 236     6  06.30(화)        창원       NC       롯데         8        10         0
# 237     6  06.30(화)        고척       키움       두산        11         2         2
# 238     7  07.01(수)        잠실       LG       KT         5        11         0
# 239     7  07.01(수)        대구       삼성       SK         7         1         2
# 240     7  07.01(수)        창원       NC       롯데         6         2         2
# 241     7  07.01(수)        광주      KIA       한화         4         3         2
# 242     7  07.01(수)        고척       키움       두산         5        14         0
# 243     7  07.02(목)        잠실       LG       KT         3         4         0
# 244     7  07.02(목)        대구       삼성       SK         6         2         2
# 245     7  07.02(목)        창원       NC       롯데         9         7         2
# 246     7  07.02(목)        광주      KIA       한화         7         1         2
# 247     7  07.02(목)        고척       키움       두산        10         7         2
# 248     7  07.03(금)        잠실       두산       한화         2         1         2
# 249     7  07.03(금)        사직       롯데       SK         4         7         0
# 250     7  07.03(금)        대구       삼성       LG         9         7         2
# 251     7  07.03(금)        창원       NC      KIA         2         8         0
# 252     7  07.03(금)        수원       KT       키움         3         2         2
# 253     7  07.04(토)        잠실       두산       한화         2         6         0
# 254     7  07.04(토)        사직       롯데       SK        10         4         2
# 255     7  07.04(토)        대구       삼성       LG         7         6         2
# 256     7  07.04(토)        창원       NC      KIA         9         2         2
# 257     7  07.04(토)        수원       KT       키움         6        10         0
# 258     7  07.05(일)        잠실       두산       한화         7         4         2
# 259     7  07.05(일)        사직       롯데       SK         3         6         0
# 260     7  07.05(일)        대구       삼성       LG         3         7         0
# 261     7  07.05(일)        창원       NC      KIA         7         6         2
# 262     7  07.05(일)        수원       KT       키움        10         5         2
# 263     7  07.07(화)        잠실       두산       LG         9         6         2
# 264     7  07.07(화)        문학       SK       NC         4         5         0
# 265     7  07.07(화)        광주      KIA       KT         2         8         0
# 266     7  07.07(화)        고척       키움       삼성         2        13         0
# 267     7  07.07(화)        대전       한화       롯데         7         6         2
# 268     7  07.08(수)        잠실       두산       LG         5         8         0
# 269     7  07.08(수)        문학       SK       NC         3         2         2
# 270     7  07.08(수)        광주      KIA       KT         4         7         0
# 271     7  07.08(수)        고척       키움       삼성         7         6         2
# 272     7  07.08(수)        대전       한화       롯데         2         6         0
# 273     7  07.09(목)        잠실       두산       LG         6         0         2
# 274     7  07.09(목)        문학       SK       NC         2         8         0
# 275     7  07.09(목)        광주      KIA       KT        10         4         2
# 276     7  07.09(목)        고척       키움       삼성         4         2         2
# 277     7  07.09(목)        대전       한화       롯데         3         5         0
# 278     7  07.10(금)        잠실       LG       NC         2        12         0
# 279     7  07.10(금)        사직       롯데       두산         5        10         0
# 280     7  07.10(금)        수원       KT       삼성         8         3         2
# 281     7  07.10(금)        광주      KIA       키움         9         8         2
# 282     7  07.10(금)        대전       한화       SK         6         5         2
# 283     7  07.11(토)        잠실       LG       NC         6         6         1
# 284     7  07.11(토)        사직       롯데       두산         5         4         2
# 285     7  07.11(토)        수원       KT       삼성        10         7         2
# 286     7  07.11(토)        광주      KIA       키움         8         3         2
# 287     7  07.11(토)        대전       한화       SK         3         5         0
# 288     7  07.13(월)        광주      KIA       키움        13         3         2
# 289     7  07.13(월)        대전       한화       SK         4         2         2
# 290     7  07.14(화)        잠실       두산       SK         7        12         0
# 291     7  07.14(화)        사직       롯데       LG         5         0         2
# 292     7  07.14(화)        대구       삼성      KIA         5         0         2
# 293     7  07.14(화)        수원       KT       한화         7         2         2
# 294     7  07.14(화)        고척       키움       NC         5         1         2
# 295     7  07.15(수)        잠실       두산       SK         7         2         2
# 296     7  07.15(수)        사직       롯데       LG         3         9         0
# 297     7  07.15(수)        대구       삼성      KIA         2         5         0
# 298     7  07.15(수)        수원       KT       한화         3         7         0
# 299     7  07.15(수)        고척       키움       NC         7         4         2
# 300     7  07.16(목)        잠실       두산       SK         4         2         2
# 301     7  07.16(목)        사직       롯데       LG        15        10         2
# 302     7  07.16(목)        대구       삼성      KIA         8         7         2
# 303     7  07.16(목)        수원       KT       한화         4         1         2
# 304     7  07.16(목)        고척       키움       NC         1         9         0
# 305     7  07.17(금)        잠실       LG       한화         8         0         2
# 306     7  07.17(금)        문학       SK       키움        12         9         2
# 307     7  07.17(금)        대구       삼성       롯데        15        10         2
# 308     7  07.17(금)        창원       NC       KT         3         3         1
# 309     7  07.17(금)        광주      KIA       두산         4         2         2
# 310     7  07.18(토)        잠실       LG       한화         3         1         2
# 311     7  07.18(토)        문학       SK       키움         1         4         0
# 312     7  07.18(토)        대구       삼성       롯데         5         2         2
# 313     7  07.18(토)        창원       NC       KT         6         1         2
# 314     7  07.18(토)        광주      KIA       두산         0         6         0
# 315     7  07.19(일)        잠실       LG       한화         6         2         2
# 316     7  07.19(일)        문학       SK       키움         4         3         2
# 317     7  07.19(일)        대구       삼성       롯데         1         2         0
# 318     7  07.19(일)        창원       NC       KT         8         2         2
# 319     7  07.19(일)        광주      KIA       두산         4         8         0
# 320     7  07.21(화)        잠실       두산       키움         6         1         2
# 321     7  07.21(화)        문학       SK       롯데         8         7         2
# 322     7  07.21(화)        창원       NC       삼성         6         5         2
# 323     7  07.21(화)        수원       KT       LG        10         9         2
# 324     7  07.21(화)        대전       한화      KIA         2        10         0
# 325     7  07.22(수)        대전       한화      KIA         1         2         0
# 326     7  07.24(금)        잠실       두산       LG         1         8         0
# 327     7  07.24(금)        수원       KT       NC         2         3         0
# 328     7  07.24(금)        고척       키움       롯데         2         4         0
# 329     7  07.24(금)        대전       한화       SK         4         7         0
# 330     7  07.25(토)        잠실       두산       LG         7         3         2
# 331     7  07.25(토)        수원       KT       NC         6         2         2
# 332     7  07.25(토)        광주      KIA       삼성         8         2         2
# 333     7  07.25(토)        고척       키움       롯데         3         6         0
# 334     7  07.26(일)        잠실       두산       LG         3         4         0
# 335     7  07.26(일)        수원       KT       NC         5         4         2
# 336     7  07.26(일)        광주      KIA       삼성         8         5         2
# 337     7  07.26(일)        고척       키움       롯데         8         1         2
# 338     7  07.26(일)        대전       한화       SK         4         7         0
# 339     7  07.27(월)        대전       한화       SK         5         5         1
# 340     7  07.28(화)        잠실       두산       키움         2         6         0
# 341     7  07.28(화)        문학       SK       LG         7        24         0
# 342     7  07.28(화)        사직       롯데       NC        11         9         2
# 343     7  07.29(수)        문학       SK       LG         6        11         0
# 344     7  07.29(수)        대구       삼성       한화         7        12         0
# 345     7  07.30(목)        잠실       두산       키움         5         8         0
# 346     7  07.30(목)        문학       SK       LG         1         9         0
# 347     7  07.30(목)        대구       삼성       한화         2         1         2
# 348     7  07.30(목)        광주      KIA       KT         1         4         0
# 349     7  07.31(금)        잠실       LG       한화         1         2         0
# 350     7  07.31(금)        사직       롯데      KIA         2         3         0
# 351     7  07.31(금)        대구       삼성       키움         3        10         0
# 352     7  07.31(금)        창원       NC       두산        10         7         2
# 353     7  07.31(금)        수원       KT       SK        11         1         2
# 354     8  08.01(토)        잠실       LG       한화         9         6         2
# 355     8  08.01(토)        사직       롯데      KIA         7         3         2
# 356     8  08.01(토)        대구       삼성       키움         7        22         0
# 357     8  08.01(토)        창원       NC       두산        10        12         0
# 358     8  08.01(토)        수원       KT       SK        11         0         2
# 359     8  08.02(일)        사직       롯데      KIA         8         0         2
# 360     8  08.02(일)        대구       삼성       키움         2         4         0
# 361     8  08.02(일)        창원       NC       두산         4         7         0
# 362     8  08.04(화)        잠실       두산       삼성         3         6         0
# 363     8  08.04(화)        문학       SK       롯데         0         8         0
# 364     8  08.04(화)        광주      KIA       LG         5        15         0
# 365     8  08.04(화)        고척       키움       KT         2         4         0
# 366     8  08.05(수)        잠실       두산       삼성         2         2         1
# 367     8  08.05(수)        광주      KIA       LG         4         6         0
# 368     8  08.05(수)        고척       키움       KT        12         3         2
# 369     8  08.05(수)        대전       한화       NC         8         5         2
# 370     8  08.06(목)        잠실       두산       삼성         5         2         2
# 371     8  08.06(목)        문학       SK       롯데         2         8         0
# 372     8  08.06(목)        광주      KIA       LG        13         1         2
# 373     8  08.06(목)        고척       키움       KT         3         2         2
# 374     8  08.06(목)        대전       한화       NC         1         4         0
# 375     8  08.07(금)        잠실       두산       롯데         4         8         0
# 376     8  08.07(금)        문학       SK       삼성         0         2         0
# 377     8  08.07(금)        고척       키움       LG         2         5         0
# 378     8  08.08(토)        잠실       두산       롯데         1         1         1
# 379     8  08.08(토)        문학       SK       삼성         4         2         2
# 380     8  08.08(토)        광주      KIA       NC         3         2         2
# 381     8  08.08(토)        고척       키움       LG         5         1         2
# 382     8  08.09(일)        광주      KIA       NC         1         8         0
# 383     8  08.09(일)        고척       키움       LG         2         1         2
# 384     8  08.09(일)        대전       한화       KT         3         6         0
# 385     8  08.11(화)        잠실       LG      KIA         4         8         0
# 386     8  08.11(화)        대구       삼성       두산         1         6         0
# 387     8  08.11(화)        수원       KT       SK         6         1         2
# 388     8  08.11(화)        고척       키움       한화         5         7         0
# 389     8  08.12(수)        잠실       LG      KIA         8         0         2
# 390     8  08.12(수)        사직       롯데       NC         8         4         2
# 391     8  08.12(수)        대구       삼성       두산         8        15         0
# 392     8  08.12(수)        수원       KT       SK         2        11         0
# 393     8  08.12(수)        고척       키움       한화         3         2         2
# 394     8  08.13(목)        잠실       LG      KIA         4         2         2
# 395     8  08.13(목)        사직       롯데       NC         2         9         0
# 396     8  08.13(목)        대구       삼성       두산         3         2         2
# 397     8  08.13(목)        수원       KT       SK         6        10         0
# 398     8  08.13(목)        고척       키움       한화         6         3         2
# 399     8  08.14(금)        잠실       두산       KT         3         5         0
# 400     8  08.14(금)        사직       롯데       키움         5         1         2
# 401     8  08.14(금)        창원       NC       LG         4        10         0
# 402     8  08.14(금)        광주      KIA       SK         7         6         2
# 403     8  08.14(금)        대전       한화       삼성         1        10         0
# 404     8  08.15(토)        잠실       두산       KT         7         5         2
# 405     8  08.15(토)        사직       롯데       키움         1         3         0
# 406     8  08.15(토)        창원       NC       LG         4        13         0
# 407     8  08.15(토)        광주      KIA       SK        10         3         2
# 408     8  08.15(토)        대전       한화       삼성         0         2         0
# 409     8  08.16(일)        잠실       두산       KT         1         4         0
# 410     8  08.16(일)        사직       롯데       키움         3         6         0
# 411     8  08.16(일)        창원       NC       LG         5         6         0
# 412     8  08.16(일)        광주      KIA       SK         8         5         2
# 413     8  08.16(일)        대전       한화       삼성         3         2         2
# 414     8  08.18(화)        잠실       LG      KIA         6         5         2
# 415     8  08.18(화)        문학       SK       한화         9         3         2
# 416     8  08.18(화)        사직       롯데       두산         2         9         0
# 417     8  08.18(화)        대구       삼성       KT         3         6         0
# 418     8  08.18(화)        창원       NC       키움         5         1         2
# 419     8  08.19(수)        잠실       LG      KIA        10         1         2
# 420     8  08.19(수)        문학       SK       한화        26         6         2
# 421     8  08.19(수)        사직       롯데       두산         7         3         2
# 422     8  08.19(수)        대구       삼성       KT         4         6         0
# 423     8  08.19(수)        창원       NC       키움         4         6         0
# 424     8  08.20(목)        잠실       두산       롯데         5         6         0
# 425     8  08.20(목)        문학       SK       삼성         3         8         0
# 426     8  08.20(목)        광주      KIA       NC         2        14         0
# 427     8  08.20(목)        고척       키움       LG         6         5         2
# 428     8  08.20(목)        대전       한화       KT         0         3         0
# 429     8  08.21(금)        잠실       두산       롯데         1         0         2
# 430     8  08.21(금)        문학       SK       삼성         8         6         2
# 431     8  08.21(금)        광주      KIA       NC         4        10         0
# 432     8  08.21(금)        고척       키움       LG         3         7         0
# 433     8  08.21(금)        대전       한화       KT         5         1         2
# 434     8  08.22(토)        문학       SK       두산         1         8         0
# 435     8  08.22(토)        대구       삼성       롯데         3         5         0
# 436     8  08.22(토)        고척       키움      KIA         4         3         2
# 437     8  08.23(일)        잠실       LG       한화         3         4         0
# 438     8  08.23(일)        문학       SK       두산         1         8         0
# 439     8  08.23(일)        대구       삼성       롯데         0        11         0
# 440     8  08.23(일)        수원       KT       NC        10         1         2
# 441     8  08.23(일)        고척       키움      KIA         7         8         0
# 442     8  08.24(월)        잠실       LG       한화         3         6         0
# 443     8  08.24(월)        수원       KT       NC         8         1         2
# 444     8  08.25(화)        잠실       두산      KIA        10         8         2
# 445     8  08.25(화)        사직       롯데       SK         8        10         0
# 446     8  08.25(화)        대구       삼성       LG         4         3         2
# 447     8  08.25(화)        창원       NC       한화        11         3         2
# 448     8  08.25(화)        수원       KT       키움         1         4         0
# 449     8  08.26(수)        잠실       두산      KIA         5         7         0
# 450     8  08.26(수)        사직       롯데       SK         3         1         2
# 451     8  08.26(수)        대구       삼성       LG         5         8         0
# 452     8  08.26(수)        창원       NC       한화         9         5         2
# 453     8  08.26(수)        수원       KT       키움         6         5         2
# 454     8  08.27(목)        잠실       LG       KT         2         0         2
# 455     8  08.27(목)        문학       SK      KIA        10         4         2
# 456     8  08.27(목)        사직       롯데       키움         6        11         0
# 457     8  08.27(목)        창원       NC       두산         8         2         2
# 458     8  08.27(목)        대전       한화       삼성         7         0         2
# 459     8  08.28(금)        잠실       LG       KT         6         5         2
# 460     8  08.28(금)        문학       SK      KIA         8        11         0
# 461     8  08.28(금)        사직       롯데       키움         4         8         0
# 462     8  08.28(금)        창원       NC       두산         4        11         0
# 463     8  08.29(토)        잠실       LG       두산         5         5         1
# 464     8  08.29(토)        사직       롯데       한화         9         7         2
# 465     8  08.29(토)        창원       NC       SK         9         5         2
# 466     8  08.29(토)        고척       키움       삼성         4         5         0
# 467     8  08.30(일)        광주      KIA       KT         5         8         0
# 468     8  08.30(일)        잠실       LG       두산         4         1         2
# 469     8  08.30(일)        사직       롯데       한화         6         2         2
# 470     8  08.30(일)        창원       NC       SK         7         4         2
# 471     8  08.30(일)        고척       키움       삼성         3         2         2
# 472     8  08.30(일)        광주      KIA       KT         7         5         2
# 473     9  09.01(화)        잠실       두산       한화         4         0         2
# 474     9  09.01(화)        문학       SK       LG         5        13         0
# 475     9  09.01(화)        수원       KT       롯데        11         2         2
# 476     9  09.01(화)        광주      KIA       삼성         6         0         2
# 477     9  09.01(화)        고척       키움       NC         2         5         0
